# %%
import torch
import local_llm as lllm

# %%
# 1. Convert TF checkpoint (one-time) and store BERT locally
assets_dir = lllm.interactive_setup_bert_base("./assets/bert-base-local")

# # OPTION 1
# # automatically search for 1) bert_model.ckpt.data-00000-of-00001 2) bert_model.ckpt.index 3) bert_model.ckpt.meta
# # in "C:/Users/Cameron.Webster/Python/local-llm/assets/uncased_L-12_H-768_A-12/" and convert to a .bin file called
# # pytorch_bert_model.bin and store that for the BERT encoder.
# lllm.setup_bert_base(
#     checkpoints="C:/Users/Cameron.Webster/Python/local-llm/assets/uncased_L-12_H-768_A-12/",
#     vocab="C:/Users/Cameron.Webster/Python/local-llm/assets/uncased_L-12_H-768_A-12/vocab.txt",
#     config="C:/Users/Cameron.Webster/Python/local-llm/assets/uncased_L-12_H-768_A-12/bert_config.json"
# )

# # OPTION 2
# lllm.setup_bert_base(
#     model_params="C:/Users/Cameron.Webster/Python/local-llm/assets/bert-base-local/pytorch_model.bin",
#     vocab="C:/Users/Cameron.Webster/Python/local-llm/assets/bert-base-local/vocab.txt",
#     config="C:/Users/Cameron.Webster/Python/local-llm/assets/config.json"
# )
# Out:
# === local-llm: BERT base setup (TF → PyTorch, fully offline) ===
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 # 1. Convert TF checkpoint (one-time) and store BERT locally
# ----> 2 assets_dir = lllm.interactive_setup_bert_base("./assets/bert-base-local")
#       4 # automatically search for 1) bert_model.ckpt.data-00000-of-00001 2) bert_model.ckpt.index 3) bert_model.ckpt.meta
#       5 # in "C:/Users/Cameron.Webster/Python/local-llm/assets/uncased_L-12_H-768_A-12/" and convert to a .bin file called
#       6 # pytorch_model.bin and store that for the BERT encoder.
#       7 lllm.setup_bert_base(
#       8     checkpoints="C:/Users/Cameron.Webster/Python/local-llm/assets/uncased_L-12_H-768_A-12/",
#       9     vocab="C:/Users/Cameron.Webster/Python/local-llm/assets/bert-base-local/vocab.txt",
# ...
